# %%
# !git clone https://github.com/sandeshsk12/telecom_churn.git
# Out:
# fatal: destination path 'telecom_churn' already exists and is not an empty directory.

# %% [markdown]
# # Telecom Churn Case study
#
# ## Business problem overview
# In the telecom industry, customers are able to choose from multiple service providers and actively switch from one operator to another. In this highly competitive market, the telecommunications industry experiences an average of 15-25% annual churn rate. Given the fact that it costs 5-10 times more to acquire a new customer than to retain an existing one, customer retention has now become even more important than customer acquisition.
# For many incumbent operators, retaining high profitable customers is the number one business goal.
#
# To reduce customer churn, telecom companies need to predict which customers are at high risk of churn.
#
# ## Business objective
# The business objective is to predict the churn in the last (i.e. the ninth) month using the data (features) from the first three months. To do this task well, understanding the typical customer behaviour during churn will be helpful.
#
#
# ## Important definitions
#
# Churn definition : Those who have not made any calls (either incoming or outgoing) AND have not used mobile internet even once in the churn phase.
#
# High Value customers : High value means recharge amount (RECH) > 70th percentile. in the first two phase.

# %% [markdown]
# # Importing necessary packages

# %%
# Packages for data manipulation
import pandas as pd
import numpy as np

# Data visualization packages
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#Supress Warnings
import warnings
warnings.filterwarnings('ignore')

#Full display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None) 
pd.set_option('display.max_colwidth', -1)

# imputers
from sklearn.impute import KNNImputer

# %% [markdown]
# # Importing data

# %%
# Reading data
original_telecom_data=pd.read_csv('/content/telecom_churn/telecom_churn_data.csv')

# %%
# Creating a copy of original data for EDA and data manipulation
telecom_data=original_telecom_data.copy()

# %% [markdown]
# # Exploring data

# %%
# Number of rows and and columns
print('Number of records: ',telecom_data.shape[0])
print()
print('Number of features: ',telecom_data.shape[1])
# Out:
# Number of records:  99999
#
# Number of features:  226

# %%
# looking at a few records 
telecom_data.sample(5)
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# 32254  7000139514     109        0.0             0.0
# 40908  7001444175     109        0.0             0.0
# 71093  7001205239     109       NaN             NaN
# 48368  7000467049     109        0.0             0.0
# 54771  7001824603     109        0.0             0.0
#
#        loc_ic_t2o_mou last_date_of_month_6 last_date_of_month_7  \
# 32254  0.0             6/30/2014            7/31/2014
# 40908  0.0             6/30/2014            7/31/2014
# 71093 NaN              6/30/2014            7/31/2014
# 48368  0.0             6/30/2014            7/31/2014
# 54771  0.0             6/30/2014            7/31/2014
#
#       last_date_of_month_8 last_date_of_month_9   arpu_6   arpu_7   arpu_8  \
# 32254  8/31/2014            9/30/2014            53.599   80.092   81.449
# 40908  8/31/2014            9/30/2014            271.734  294.686  0.000
# ...

# %%
#using info() to understand the data types of the columns
telecom_data.info(show_counts=True,verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 226 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    mobile_number             99999 non-null  int64
#  1    circle_id                 99999 non-null  int64
#  2    loc_og_t2o_mou            98981 non-null  float64
#  3    std_og_t2o_mou            98981 non-null  float64
#  4    loc_ic_t2o_mou            98981 non-null  float64
#  5    last_date_of_month_6      99999 non-null  object
#  6    last_date_of_month_7      99398 non-null  object
#  7    last_date_of_month_8      98899 non-null  object
#  8    last_date_of_month_9      98340 non-null  object
#  9    arpu_6                    99999 non-null  float64
#  10   arpu_7                    99999 non-null  float64
#  11   arpu_8                    99999 non-null  float64
#  12   arpu_9                    99999 non-null  float64
# ...

# %% [markdown]
# ---
# > Observation
#
# 1. There are 179 float columns, 35 integer columns and 12 object columns
# 2. Almost all the columns aare of integer type
# 3. Columns with "date" in them are of object type
#
# ---

# %%
# describe the data
telecom_data.describe()
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count  9.999900e+04   99999.0    98981.0         98981.0
# mean   7.001207e+09   109.0      0.0             0.0
# std    6.956694e+05   0.0        0.0             0.0
# min    7.000000e+09   109.0      0.0             0.0
# 25%    7.000606e+09   109.0      0.0             0.0
# 50%    7.001205e+09   109.0      0.0             0.0
# 75%    7.001812e+09   109.0      0.0             0.0
# max    7.002411e+09   109.0      0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8        arpu_9  \
# count  98981.0         99999.000000  99999.000000  99999.000000  99999.000000
# mean   0.0             282.987358    278.536648    279.154731    261.645069
# std    0.0             328.439770    338.156291    344.474791    341.998630
# min    0.0            -2258.709000  -2014.045000  -945.808000   -1899.505000
# 25%    0.0             93.411500     86.980500     84.126000     62.685000
# ...

# %%
# describe the object datatype
telecom_data.describe(include=['O'])
# Out:
#        last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# count   99999                99398                98899
# unique  1                    1                    1
# top     6/30/2014            7/31/2014            8/31/2014
# freq    99999                99398                98899
#
#        last_date_of_month_9 date_of_last_rech_6 date_of_last_rech_7  \
# count   98340                98392               98232
# unique  1                    30                  31
# top     9/30/2014            6/30/2014           7/31/2014
# freq    98340                16960               17288
#
#        date_of_last_rech_8 date_of_last_rech_9 date_of_last_rech_data_6  \
# count   96377               95239               25153
# unique  31                  30                  30
# top     8/31/2014           9/29/2014           6/30/2014
# freq    14706               22623               1888
#
#        date_of_last_rech_data_7 date_of_last_rech_data_8  \
# ...

# %% [markdown]
# ---
# > Observation
#
# last_date_of_month_7,last_date_of_month_8,last_date_of_month_9 have only 1 value and hence can be dropeed later
#
# ---

# %% [markdown]
# # Data cleaning and manipulation - Part 1

# %% [markdown]
# ---
# > **NOTE**
#
# We first create a dataset that only includes the high value customers and also contains the target vairable 'Churn'. In the second part of Data cleaning, we will clean and manipulate the new dataset

# %% [markdown]
# ## Data cleaning

# %%
# Dropping duplicate rows if any

print('Record before dropping duplicates',telecom_data.shape[0])
telecom_data=telecom_data.drop_duplicates()
print('Record after dropping duplicates',telecom_data.shape[0])
# Out:
# Record before dropping duplicates 99999
# Record after dropping duplicates 99999

# %% [markdown]
# ---
#
# > Observation
#
#  There are no duplicate rows
#
#  ---

# %%
def missing_count(df):
    missing=df.isna().sum()
    sorted_missing = missing.sort_values(ascending=False)
    missing_percent = 100*sorted_missing/len(df)
    missing_percent_df = pd.DataFrame(missing_percent,columns=['missing %'])
    return missing_percent_df

# %%
missing_count(telecom_data)
# Out:
#                           missing %
# arpu_3g_6                 74.846748
# night_pck_user_6          74.846748
# total_rech_data_6         74.846748
# arpu_2g_6                 74.846748
# max_rech_data_6           74.846748
# fb_user_6                 74.846748
# av_rech_amt_data_6        74.846748
# date_of_last_rech_data_6  74.846748
# count_rech_2g_6           74.846748
# count_rech_3g_6           74.846748
# date_of_last_rech_data_7  74.428744
# total_rech_data_7         74.428744
# fb_user_7                 74.428744
# max_rech_data_7           74.428744
# night_pck_user_7          74.428744
# count_rech_2g_7           74.428744
# av_rech_amt_data_7        74.428744
# arpu_2g_7                 74.428744
# count_rech_3g_7           74.428744
# arpu_3g_7                 74.428744
# total_rech_data_9         74.077741
# count_rech_3g_9           74.077741
# fb_user_9                 74.077741
# max_rech_data_9           74.077741
# arpu_3g_9                 74.077741
# ...

# %%
telecom_data.columns.to_list()
# Out:
# ['mobile_number',
#  'circle_id',
#  'loc_og_t2o_mou',
#  'std_og_t2o_mou',
#  'loc_ic_t2o_mou',
#  'last_date_of_month_6',
#  'last_date_of_month_7',
#  'last_date_of_month_8',
#  'last_date_of_month_9',
#  'arpu_6',
#  'arpu_7',
#  'arpu_8',
#  'arpu_9',
#  'onnet_mou_6',
#  'onnet_mou_7',
#  'onnet_mou_8',
#  'onnet_mou_9',
#  'offnet_mou_6',
#  'offnet_mou_7',
#  'offnet_mou_8',
#  'offnet_mou_9',
#  'roam_ic_mou_6',
#  'roam_ic_mou_7',
#  'roam_ic_mou_8',
#  'roam_ic_mou_9',
#  'roam_og_mou_6',
#  'roam_og_mou_7',
#  'roam_og_mou_8',
#  'roam_og_mou_9',
#  'loc_og_t2t_mou_6',
#  'loc_og_t2t_mou_7',
#  'loc_og_t2t_mou_8',
#  'loc_og_t2t_mou_9',
#  'loc_og_t2m_mou_6',
#  'loc_og_t2m_mou_7',
#  'loc_og_t2m_mou_8',
#  'loc_og_t2m_mou_9',
#  'loc_og_t2f_mou_6',
#  'loc_og_t2f_mou_7',
#  'loc_og_t2f_mou_8',
#  'loc_og_t2f_mou_9',
#  'loc_og_t2c_mou_6',
#  'loc_og_t2c_mou_7',
#  'loc_og_t2c_mou_8',
#  'loc_og_t2c_mou_9',
#  'loc_og_mou_6',
#  'loc_og_mou_7',
#  'loc_og_mou_8',
# ...

# %% [markdown]
# ---
# > Observation
#
# Of all the recharge columns, 4 of them were identified to have a wrong spelling. We correct this  in order to make the process of identifying high value customers easier.
#
# The four columns are
#  'last_day_rch_amt_6',
#  'last_day_rch_amt_7',
#  'last_day_rch_amt_8',
#  'last_day_rch_amt_9'
#
#  ---

# %%
# Rectifying spelling mistake
cols=[]
for col in telecom_data.columns.to_list():
    if 'rch' in col:
        col=col.replace('rch','rech')
        cols.append(col)
    else:
        cols.append(col)

telecom_data.columns=cols
cols
# Out:
# ['mobile_number',
#  'circle_id',
#  'loc_og_t2o_mou',
#  'std_og_t2o_mou',
#  'loc_ic_t2o_mou',
#  'last_date_of_month_6',
#  'last_date_of_month_7',
#  'last_date_of_month_8',
#  'last_date_of_month_9',
#  'arpu_6',
#  'arpu_7',
#  'arpu_8',
#  'arpu_9',
#  'onnet_mou_6',
#  'onnet_mou_7',
#  'onnet_mou_8',
#  'onnet_mou_9',
#  'offnet_mou_6',
#  'offnet_mou_7',
#  'offnet_mou_8',
#  'offnet_mou_9',
#  'roam_ic_mou_6',
#  'roam_ic_mou_7',
#  'roam_ic_mou_8',
#  'roam_ic_mou_9',
#  'roam_og_mou_6',
#  'roam_og_mou_7',
#  'roam_og_mou_8',
#  'roam_og_mou_9',
#  'loc_og_t2t_mou_6',
#  'loc_og_t2t_mou_7',
#  'loc_og_t2t_mou_8',
#  'loc_og_t2t_mou_9',
#  'loc_og_t2m_mou_6',
#  'loc_og_t2m_mou_7',
#  'loc_og_t2m_mou_8',
#  'loc_og_t2m_mou_9',
#  'loc_og_t2f_mou_6',
#  'loc_og_t2f_mou_7',
#  'loc_og_t2f_mou_8',
#  'loc_og_t2f_mou_9',
#  'loc_og_t2c_mou_6',
#  'loc_og_t2c_mou_7',
#  'loc_og_t2c_mou_8',
#  'loc_og_t2c_mou_9',
#  'loc_og_mou_6',
#  'loc_og_mou_7',
#  'loc_og_mou_8',
# ...

# %%
telecom_data.head(2)
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0  7000842753     109        0.0             0.0             0.0
# 1  7001865778     109        0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0  6/30/2014            7/31/2014            8/31/2014
# 1  6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6   arpu_7   arpu_8  arpu_9  onnet_mou_6  \
# 0  9/30/2014            197.385  214.816  213.803  21.100 NaN
# 1  9/30/2014            34.047   355.074  268.321  86.285  24.11
#
#    onnet_mou_7  onnet_mou_8  onnet_mou_9  offnet_mou_6  offnet_mou_7  \
# 0 NaN           0.00        NaN          NaN           NaN
# 1  78.68        7.68         18.34        15.74         99.84
#
#    offnet_mou_8  offnet_mou_9  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  \
# 0  0.00         NaN           NaN            NaN             0.0
# ...

# %% [markdown]
# ---
# > Note:
#
# The objective of the analysis is to identify the churn of high value customers. High value customers are those whose recharge amount is more than the 70th percentile in the first two phase.
#
# The phases involve
# 1. good phase ( month 6 and month 7)
# 2. action phase ( month 8)
# 3. Churn phase ( month 9)
#
# Of the three, we consider the good phase and the action phase (ie. month 6,7 and 8) to identify the high value customers
#
# ---

# %% [raw]
# #columns having recharge
# recharge_cols =[x if 'rech' in x else False for x in telecom_data.columns.to_list() ]

# %%
#copied
rech_amt_data_cols = telecom_data.columns[telecom_data.columns.str.contains('rech_amt|rech_data', regex=True)]
rech_amt_data_cols
# Out:
# Index(['total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8',
#        'total_rech_amt_9', 'max_rech_amt_6', 'max_rech_amt_7',
#        'max_rech_amt_8', 'max_rech_amt_9', 'last_day_rech_amt_6',
#        'last_day_rech_amt_7', 'last_day_rech_amt_8', 'last_day_rech_amt_9',
#        'date_of_last_rech_data_6', 'date_of_last_rech_data_7',
#        'date_of_last_rech_data_8', 'date_of_last_rech_data_9',
#        'total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8',
#        'total_rech_data_9', 'max_rech_data_6', 'max_rech_data_7',
#        'max_rech_data_8', 'max_rech_data_9', 'av_rech_amt_data_6',
#        'av_rech_amt_data_7', 'av_rech_amt_data_8', 'av_rech_amt_data_9'],
#       dtype='object')

# %% [markdown]
# ---
# > Observation
#
# The above list corresponds to
#
# Recharge Amount
# 1. total reacharge amount
# 2. max_recharge amount
# 3. total recharge data
# 4. max recharge data
# 5. average recharge amount data
#
# Recharge date
# 1. last date recharge amount
# 2. date of last recharge data
#
#
# Of the above columns, we are interested in the columns pertaining to recharge amount as it will help us in determining the high value customers. Of these, columns realting to month 6,7 and 8 are useful
#
# ---

# %%
# important recharge amount
recharge_amount_cols=['total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8',
       'total_rech_amt_9', 'max_rech_amt_6', 'max_rech_amt_7',
       'max_rech_amt_8', 'max_rech_amt_9',        
       'total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8',
       'total_rech_data_9', 'max_rech_data_6', 'max_rech_data_7',
       'max_rech_data_8', 'max_rech_data_9', 'av_rech_amt_data_6',
       'av_rech_amt_data_7', 'av_rech_amt_data_8', 'av_rech_amt_data_9']

# %%
missing_count(telecom_data[recharge_amount_cols])
# Out:
#                     missing %
# av_rech_amt_data_6  74.846748
# total_rech_data_6   74.846748
# max_rech_data_6     74.846748
# av_rech_amt_data_7  74.428744
# max_rech_data_7     74.428744
# total_rech_data_7   74.428744
# av_rech_amt_data_9  74.077741
# total_rech_data_9   74.077741
# max_rech_data_9     74.077741
# av_rech_amt_data_8  73.660737
# max_rech_data_8     73.660737
# total_rech_data_8   73.660737
# total_rech_amt_7    0.000000
# max_rech_amt_9      0.000000
# max_rech_amt_8      0.000000
# max_rech_amt_7      0.000000
# max_rech_amt_6      0.000000
# total_rech_amt_9    0.000000
# total_rech_amt_8    0.000000
# total_rech_amt_6    0.000000

# %% [markdown]
# ---
# > Observation
#
# We find that columns involving data have a lot of missing values (~75%) while for the call based recharge, there are no missing values.
#
# This might be because users might not be recharging for data and rather recharge only for the call facilities. Hence we impute these columns with 0. We use a basic imputer instead of KNN imputer or iterative imputer as we already know the value to be imputed

# %%
# imputing recharge columns with 0 wherever missing
telecom_data[recharge_amount_cols]=telecom_data[recharge_amount_cols].fillna(0)

# %%
telecom_data[recharge_amount_cols].describe()
# Out:
#        total_rech_amt_6  total_rech_amt_7  total_rech_amt_8  total_rech_amt_9  \
# count  99999.000000      99999.000000      99999.000000      99999.000000
# mean   327.514615        322.962970        324.157122        303.345673
# std    398.019701        408.114237        416.540455        404.588583
# min    0.000000          0.000000          0.000000          0.000000
# 25%    109.000000        100.000000        90.000000         52.000000
# 50%    230.000000        220.000000        225.000000        200.000000
# 75%    437.500000        428.000000        434.500000        415.000000
# max    35190.000000      40335.000000      45320.000000      37235.000000
#
#        max_rech_amt_6  max_rech_amt_7  max_rech_amt_8  max_rech_amt_9  \
# count  99999.000000    99999.000000    99999.000000    99999.000000
# mean   104.637486      104.752398      107.728207      101.943889
# std    120.614894      124.523970      126.902505      125.375109
# ...

# %%
telecom_data[recharge_amount_cols].head(10)
# Out:
#    total_rech_amt_6  total_rech_amt_7  total_rech_amt_8  total_rech_amt_9  \
# 0  362               252               252               0
# 1  74                384               283               121
# 2  168               315               116               358
# 3  230               310               601               410
# 4  196               350               287               200
# 5  120               0                 130               130
# 6  499               222               294               141
# 7  1580              790               3638              0
# 8  437               601               120               186
# 9  220               195               210               180
#
#    max_rech_amt_6  max_rech_amt_7  max_rech_amt_8  max_rech_amt_9  \
# 0  252             252             252             0
# 1  44              154             65              50
# 2  86              200             86              100
# ...

# %% [markdown]
# ## Filtering high value users

# %% [markdown]
# ---
# > **NOTE**
#
# We define high-value customers as follows: Those who have recharged with an amount more than or equal to X, where X is the 70th percentile of the average recharge amount in the first two months (the good phase).
#
# ---

# %%
# Deriving new features for total recharge amount during good phase
telecom_data['total_recharge_amount']=telecom_data['total_rech_data_6']+telecom_data['total_rech_data_7']+ telecom_data['total_rech_amt_6']+ telecom_data['total_rech_amt_7']

# %%
# Calculating the 70th percentile
recharge_amount_70_percentile=telecom_data['total_recharge_amount'].quantile(0.7)

recharge_amount_70_percentile
# Out:
# 739.0

# %%
# Filtering out high value customers
high_value_users_data=telecom_data[(telecom_data.total_recharge_amount >= recharge_amount_70_percentile)]
high_value_users_data.head(5)
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 7   7000701601     109        0.0             0.0             0.0
# 8   7001524846     109        0.0             0.0             0.0
# 13  7002191713     109        0.0             0.0             0.0
# 16  7000875565     109        0.0             0.0             0.0
# 17  7000187447     109        0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 7   6/30/2014            7/31/2014            8/31/2014
# 8   6/30/2014            7/31/2014            8/31/2014
# 13  6/30/2014            7/31/2014            8/31/2014
# 16  6/30/2014            7/31/2014            8/31/2014
# 17  6/30/2014            7/31/2014            8/31/2014
#
#    last_date_of_month_9    arpu_6    arpu_7    arpu_8   arpu_9  onnet_mou_6  \
# 7   9/30/2014            1069.180  1349.850  3171.480  500.000  57.84
# ...

# %%
high_value_users_data.shape
# Out:
# (30019, 227)

# %% [markdown]
# ## Churned users

# %% [markdown]
# ---
#
# > **NOTE**
#
# We define churned users as those who have not made any calls (either incoming or outgoing) AND have not used mobile internet even once in the churn phase.
#
# The related attributes are
#
# 1. total_ic_mou_9
# 2. total_og_mou_9
# 3. vol_2g_mb_9
# 4. vol_3g_mb_9
#
#
#
# ---

# %%
# Churn indicators
churn_indicators=['total_ic_mou_9','total_og_mou_9','vol_2g_mb_9','vol_3g_mb_9']

# %%
high_value_users_data['total_usage']=high_value_users_data[churn_indicators].sum(axis=1)

# %%
churn_data=high_value_users_data.copy()
churn_data['churn']=high_value_users_data['total_usage'].apply(lambda x: 1 if x==0 else 0)
churn_data.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 7   7000701601     109        0.0             0.0             0.0
# 8   7001524846     109        0.0             0.0             0.0
# 13  7002191713     109        0.0             0.0             0.0
# 16  7000875565     109        0.0             0.0             0.0
# 17  7000187447     109        0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 7   6/30/2014            7/31/2014            8/31/2014
# 8   6/30/2014            7/31/2014            8/31/2014
# 13  6/30/2014            7/31/2014            8/31/2014
# 16  6/30/2014            7/31/2014            8/31/2014
# 17  6/30/2014            7/31/2014            8/31/2014
#
#    last_date_of_month_9    arpu_6    arpu_7    arpu_8   arpu_9  onnet_mou_6  \
# 7   9/30/2014            1069.180  1349.850  3171.480  500.000  57.84
# ...

# %%
imbalance_percentage = 100*churn_data[churn_data['churn']==1].shape[0] / churn_data.shape[0]
imbalance_percentage
# Out:
# 8.627869016289683

# %% [markdown]
# ---
# > OBSERVATION
#
# We calulate the impablance Percentage to be 8.62 % which indicates that the dataset is highly imbalanced. In simpler words, we have way more data of users not churning than data of users churning.
#
# ---

# %%
churn_data.columns
# Out:
# Index(['mobile_number', 'circle_id', 'loc_og_t2o_mou', 'std_og_t2o_mou',
#        'loc_ic_t2o_mou', 'last_date_of_month_6', 'last_date_of_month_7',
#        'last_date_of_month_8', 'last_date_of_month_9', 'arpu_6', 'arpu_7',
#        'arpu_8', 'arpu_9', 'onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8',
#        'onnet_mou_9', 'offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8',
#        'offnet_mou_9', 'roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8',
#        'roam_ic_mou_9', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8',
#        'roam_og_mou_9', 'loc_og_t2t_mou_6', 'loc_og_t2t_mou_7',
#        'loc_og_t2t_mou_8', 'loc_og_t2t_mou_9', 'loc_og_t2m_mou_6',
#        'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2m_mou_9',
#        'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8',
#        'loc_og_t2f_mou_9', 'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7',
#        'loc_og_t2c_mou_8', 'loc_og_t2c_mou_9', 'loc_og_mou_6', 'loc_og_mou_7',
# ...

# %%
print('Attribtes related to the churn phase are:')
print()

attributes_9th_month=[]
for col in churn_data.columns.to_list():
    if '_9' in col:
        print(col)
        attributes_9th_month.append(col)
    elif 'sep' in col :
        print(col)
        attributes_9th_month.append(col)
    else:
        pass
# Out:
# Attribtes related to the churn phase are:
#
# last_date_of_month_9
# arpu_9
# onnet_mou_9
# offnet_mou_9
# roam_ic_mou_9
# roam_og_mou_9
# loc_og_t2t_mou_9
# loc_og_t2m_mou_9
# loc_og_t2f_mou_9
# loc_og_t2c_mou_9
# loc_og_mou_9
# std_og_t2t_mou_9
# std_og_t2m_mou_9
# std_og_t2f_mou_9
# std_og_t2c_mou_9
# std_og_mou_9
# isd_og_mou_9
# spl_og_mou_9
# og_others_9
# total_og_mou_9
# loc_ic_t2t_mou_9
# loc_ic_t2m_mou_9
# loc_ic_t2f_mou_9
# loc_ic_mou_9
# std_ic_t2t_mou_9
# std_ic_t2m_mou_9
# std_ic_t2f_mou_9
# std_ic_t2o_mou_9
# std_ic_mou_9
# total_ic_mou_9
# spl_ic_mou_9
# isd_ic_mou_9
# ic_others_9
# total_rech_num_9
# total_rech_amt_9
# max_rech_amt_9
# date_of_last_rech_9
# last_day_rech_amt_9
# date_of_last_rech_data_9
# total_rech_data_9
# max_rech_data_9
# count_rech_2g_9
# count_rech_3g_9
# av_rech_amt_data_9
# vol_2g_mb_9
# vol_3g_mb_9
# arpu_3g_9
# arpu_2g_9
# night_pck_user_9
# monthly_2g_9
# sachet_2g_9
# monthly_3g_9
# sachet_3g_9
# fb_user_9
# sep_vbc_3g

# %%
print('Attribtes related to the churn phase are:')
print(attributes_9th_month)
# Out:
# Attribtes related to the churn phase are:
# ...

# %% [markdown]
# ---
#
# > Note
#
# We drop columns related to the churn phase as this would lead to data leakage
#
# ---

# %%
# dropping 9th month columns
churn_data.drop(attributes_9th_month,axis=1,inplace=True)

# %%
churn_data.shape
# Out:
# (30019, 174)

# %%
churn_data.dropna(axis=0,thresh=0.7*174).shape
# Out:
# (29732, 174)

# %% [markdown]
# # Data manipulation and cleaning -2

# %% [markdown]
# Now that we have completed creating our dataset, we shall clean it and manipulate it as necessary

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Dropping columns with unique values

# %% [markdown]
# ### Removing columns with constant variance

# %%
const_variance_columns=[]
for col in churn_data.columns.to_list():
    const_variance_value=churn_data[col].value_counts(normalize=True).values[0]
    if (col!='churn') & (const_variance_value*100 == 100):
        const_variance_columns.append(col)

# %%
len(const_variance_columns)
# Out:
# 13

# %%
churn_data['night_pck_user_6'].value_counts()
# Out:
# 0.0    11130
# 1.0    314
# Name: night_pck_user_6, dtype: int64

# %%
const_variance_columns
# Out:
# ['circle_id',
#  'loc_og_t2o_mou',
#  'std_og_t2o_mou',
#  'loc_ic_t2o_mou',
#  'last_date_of_month_6',
#  'last_date_of_month_7',
#  'last_date_of_month_8',
#  'std_og_t2c_mou_6',
#  'std_og_t2c_mou_7',
#  'std_og_t2c_mou_8',
#  'std_ic_t2o_mou_6',
#  'std_ic_t2o_mou_7',
#  'std_ic_t2o_mou_8']

# %%
churn_data.drop(const_variance_columns,axis=1,inplace=True)

# %%
churn_data.shape
# Out:
# (30019, 161)

# %%
#copied

##Since this is not a time-series based analysis, we might also eliminate date columns as they won't be useful for our analysis
date_columns_list= list(churn_data.columns[churn_data.columns.str.contains('date')])
print(date_columns_list)



##Dropping the date columns
churn_data.drop(date_columns_list, axis=1, inplace=True)
churn_data.head()
# Out:
# ['date_of_last_rech_6', 'date_of_last_rech_7', 'date_of_last_rech_8', 'date_of_last_rech_data_6', 'date_of_last_rech_data_7', 'date_of_last_rech_data_8']
#     mobile_number    arpu_6    arpu_7    arpu_8  onnet_mou_6  onnet_mou_7  \
# 7   7000701601     1069.180  1349.850  3171.480  57.84        54.68
# 8   7001524846     378.721   492.223   137.362   413.69       351.03
# 13  7002191713     492.846   205.671   593.260   501.76       108.39
# 16  7000875565     430.975   299.869   187.894   50.51        74.01
# 17  7000187447     690.008   18.980    25.499    1185.91      9.28
#
#     onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  roam_ic_mou_6  \
# 7   52.29        453.43        567.16        325.91        16.23
# 8   35.08        94.66         80.63         136.48        0.00
# 13  534.24       413.31        119.28        482.46        23.53
# 16  70.61        296.29        229.74        162.76        0.00
# 17  7.79         61.64         0.00          5.54          0.00
#
# ...

# %%
cols_2g_3g= list(churn_data.columns[churn_data.columns.str.contains('2g|3g')])
cols_2g_3g
# Out:
# ['count_rech_2g_6',
#  'count_rech_2g_7',
#  'count_rech_2g_8',
#  'count_rech_3g_6',
#  'count_rech_3g_7',
#  'count_rech_3g_8',
#  'vol_2g_mb_6',
#  'vol_2g_mb_7',
#  'vol_2g_mb_8',
#  'vol_3g_mb_6',
#  'vol_3g_mb_7',
#  'vol_3g_mb_8',
#  'arpu_3g_6',
#  'arpu_3g_7',
#  'arpu_3g_8',
#  'arpu_2g_6',
#  'arpu_2g_7',
#  'arpu_2g_8',
#  'monthly_2g_6',
#  'monthly_2g_7',
#  'monthly_2g_8',
#  'sachet_2g_6',
#  'sachet_2g_7',
#  'sachet_2g_8',
#  'monthly_3g_6',
#  'monthly_3g_7',
#  'monthly_3g_8',
#  'sachet_3g_6',
#  'sachet_3g_7',
#  'sachet_3g_8',
#  'aug_vbc_3g',
#  'jul_vbc_3g',
#  'jun_vbc_3g']

# %%
missing_count(churn_data[cols_2g_3g])
# Out:
#                  missing %
# count_rech_2g_6  61.877478
# arpu_3g_6        61.877478
# count_rech_3g_6  61.877478
# arpu_2g_6        61.877478
# count_rech_2g_7  60.994703
# arpu_3g_7        60.994703
# arpu_2g_7        60.994703
# count_rech_3g_7  60.994703
# count_rech_3g_8  60.721543
# arpu_3g_8        60.721543
# count_rech_2g_8  60.721543
# arpu_2g_8        60.721543
# vol_2g_mb_7      0.000000
# sachet_2g_8      0.000000
# jul_vbc_3g       0.000000
# aug_vbc_3g       0.000000
# sachet_3g_8      0.000000
# sachet_3g_7      0.000000
# sachet_3g_6      0.000000
# monthly_3g_8     0.000000
# monthly_3g_7     0.000000
# monthly_3g_6     0.000000
# monthly_2g_8     0.000000
# sachet_2g_7      0.000000
# sachet_2g_6      0.000000
# vol_2g_mb_8      0.000000
# monthly_2g_7     0.000000
# monthly_2g_6     0.000000
# vol_2g_mb_6      0.000000
# vol_3g_mb_8      0.000000
# vol_3g_mb_7      0.000000
# vol_3g_mb_6      0.000000
# jun_vbc_3g       0.000000

# %% [markdown]
# we can see that for the
#
# 1. 6th month , missing values are <br>
# count_rech_2g_6 	61.877478 <br>
# count_rech_3g_6 	61.877478<br>
# arpu_3g_6 	61.877478<br>
# arpu_2g_6 	61.877478<br>

# %% [markdown]
# count reach -> no recharges so no internet usage
# no internet usage so no revenue generated
#
# means, they dont use internet, so impute to zero

# %%
churn_data[cols_2g_3g]=churn_data[cols_2g_3g].fillna(0,axis=1)

# %%
fb_and_night_cols= list(churn_data.columns[churn_data.columns.str.contains('fb|night')])
fb_and_night_cols
# Out:
# ['night_pck_user_6',
#  'night_pck_user_7',
#  'night_pck_user_8',
#  'fb_user_6',
#  'fb_user_7',
#  'fb_user_8']

# %% [markdown]
# fb user has same number of missing values as count reach, indicating no internet -> no  facebook
# so we impute 0, indicating not using facebook

# %%
churn_data[fb_and_night_cols]=churn_data[fb_and_night_cols].fillna(0,axis=1)

# %% [markdown]
# ##### Only mou left

# %%
mou_6_cols= list(churn_data.columns[churn_data.columns.str.contains('mou_6')])
mou_6_cols
# Out:
# ['onnet_mou_6',
#  'offnet_mou_6',
#  'roam_ic_mou_6',
#  'roam_og_mou_6',
#  'loc_og_t2t_mou_6',
#  'loc_og_t2m_mou_6',
#  'loc_og_t2f_mou_6',
#  'loc_og_t2c_mou_6',
#  'loc_og_mou_6',
#  'std_og_t2t_mou_6',
#  'std_og_t2m_mou_6',
#  'std_og_t2f_mou_6',
#  'std_og_mou_6',
#  'isd_og_mou_6',
#  'spl_og_mou_6',
#  'total_og_mou_6',
#  'loc_ic_t2t_mou_6',
#  'loc_ic_t2m_mou_6',
#  'loc_ic_t2f_mou_6',
#  'loc_ic_mou_6',
#  'std_ic_t2t_mou_6',
#  'std_ic_t2m_mou_6',
#  'std_ic_t2f_mou_6',
#  'std_ic_mou_6',
#  'total_ic_mou_6',
#  'spl_ic_mou_6',
#  'isd_ic_mou_6']

# %%
churn_data[mou_6_cols][churn_data['onnet_mou_6'].isna()].sample(10)
# Out:
#        onnet_mou_6  offnet_mou_6  roam_ic_mou_6  roam_og_mou_6  \
# 47642 NaN          NaN           NaN            NaN
# 39382 NaN          NaN           NaN            NaN
# 20116 NaN          NaN           NaN            NaN
# 60166 NaN          NaN           NaN            NaN
# 90251 NaN          NaN           NaN            NaN
# 30967 NaN          NaN           NaN            NaN
# 30815 NaN          NaN           NaN            NaN
# 52633 NaN          NaN           NaN            NaN
# 9944  NaN          NaN           NaN            NaN
# 44010 NaN          NaN           NaN            NaN
#
#        loc_og_t2t_mou_6  loc_og_t2m_mou_6  loc_og_t2f_mou_6  loc_og_t2c_mou_6  \
# 47642 NaN               NaN               NaN               NaN
# 39382 NaN               NaN               NaN               NaN
# 20116 NaN               NaN               NaN               NaN
# 60166 NaN               NaN               NaN               NaN
# ...

# %% [markdown]
# It appears that when the total incoming calls duration is 0, all the other mou parameters related to incoming calls are missing. Hence we impute it with zero.
# similarly, It appears that when the total outgoing calls duration is 0, all the other mou parameters related to outgoing calls are missing. Hence we impute it with zero

# %%
mou_cols= list(churn_data.columns[churn_data.columns.str.contains('mou')])
churn_data[mou_cols]=churn_data[mou_cols].fillna(0,axis=1)

# %%
missing_count(churn_data[mou_cols])
# Out:
#                        missing %
# onnet_mou_6            0.0
# std_ic_t2t_mou_7       0.0
# loc_ic_mou_8           0.0
# loc_ic_mou_7           0.0
# loc_ic_mou_6           0.0
# loc_ic_t2f_mou_8       0.0
# loc_ic_t2f_mou_7       0.0
# loc_ic_t2f_mou_6       0.0
# loc_ic_t2m_mou_8       0.0
# loc_ic_t2m_mou_7       0.0
# loc_ic_t2m_mou_6       0.0
# loc_ic_t2t_mou_8       0.0
# loc_ic_t2t_mou_7       0.0
# loc_ic_t2t_mou_6       0.0
# total_og_mou_8         0.0
# total_og_mou_7         0.0
# total_og_mou_6         0.0
# spl_og_mou_8           0.0
# spl_og_mou_7           0.0
# std_ic_t2t_mou_6       0.0
# std_ic_t2t_mou_8       0.0
# onnet_mou_7            0.0
# std_ic_t2m_mou_6       0.0
# isd_ic_mou_8           0.0
# isd_ic_mou_7           0.0
# isd_ic_mou_6           0.0
# spl_ic_mou_8           0.0
# spl_ic_mou_7           0.0
# spl_ic_mou_6           0.0
# total_ic_mou_8         0.0
# total_ic_mou_7         0.0
# total_ic_mou_6         0.0
# std_ic_mou_8           0.0
# ...

# %%
imputer = KNNImputer(n_neighbors=5)
churn_data=pd.DataFrame(imputer.fit_transform(churn_data),columns=churn_data.columns)

# %%
missing_count(churn_data)
# Out:
#                        missing %
# mobile_number          0.0
# max_rech_data_6        0.0
# max_rech_amt_8         0.0
# last_day_rech_amt_6    0.0
# last_day_rech_amt_7    0.0
# last_day_rech_amt_8    0.0
# total_rech_data_6      0.0
# total_rech_data_7      0.0
# total_rech_data_8      0.0
# max_rech_data_7        0.0
# av_rech_amt_data_7     0.0
# max_rech_data_8        0.0
# count_rech_2g_6        0.0
# count_rech_2g_7        0.0
# count_rech_2g_8        0.0
# count_rech_3g_6        0.0
# count_rech_3g_7        0.0
# count_rech_3g_8        0.0
# max_rech_amt_7         0.0
# max_rech_amt_6         0.0
# total_rech_amt_8       0.0
# total_rech_amt_7       0.0
# total_ic_mou_7         0.0
# total_ic_mou_8         0.0
# spl_ic_mou_6           0.0
# spl_ic_mou_7           0.0
# spl_ic_mou_8           0.0
# isd_ic_mou_6           0.0
# isd_ic_mou_7           0.0
# isd_ic_mou_8           0.0
# ic_others_6            0.0
# ic_others_7            0.0
# ic_others_8            0.0
# ...

# %% [markdown]
# # EDA

# %%
# creating a copy of data for EDA
churn_data_eda=churn_data.copy()

# %% [markdown]
# ## Identifying categorical columns

# %%
# identifying potential categorical columns

for col in churn_data_eda.columns:
    if churn_data_eda[col].nunique() <= 10:
        print('The column',col,'has',churn_data_eda[col].nunique(),'unique values')
    else:
        pass
# Out:
# The column night_pck_user_6 has 2 unique values
# The column night_pck_user_7 has 2 unique values
# The column night_pck_user_8 has 2 unique values
# The column monthly_2g_6 has 5 unique values
# The column monthly_2g_7 has 6 unique values
# The column monthly_2g_8 has 6 unique values
# The column fb_user_6 has 2 unique values
# The column fb_user_7 has 2 unique values
# The column fb_user_8 has 2 unique values
# The column churn has 2 unique values

# %% [markdown]
# Of all the above columns, churn, night_pck_user_* and fb_user_* are categorical in nature whereas monthly_2g_* is continuous in nature.

# %%
cat_cols=['night_pck_user_6','night_pck_user_7','night_pck_user_8','fb_user_6','fb_user_7','fb_user_8','churn']
num_cols=list(set(churn_data_eda.columns.to_list())-set(cat_cols))
# remove churn from cat_cols as it is target variable
cat_cols.remove('churn')

# %%
num_cols
# Out:
# ['std_og_t2t_mou_7',
#  'sachet_2g_8',
#  'loc_og_t2f_mou_8',
#  'av_rech_amt_data_6',
#  'std_og_t2m_mou_6',
#  'arpu_7',
#  'loc_ic_t2t_mou_6',
#  'loc_ic_t2f_mou_6',
#  'std_ic_t2m_mou_6',
#  'total_rech_data_6',
#  'total_og_mou_6',
#  'std_og_mou_7',
#  'std_og_t2t_mou_6',
#  'total_rech_amt_8',
#  'std_og_mou_6',
#  'loc_og_t2f_mou_7',
#  'last_day_rech_amt_6',
#  'loc_ic_t2f_mou_8',
#  'last_day_rech_amt_7',
#  'sachet_3g_6',
#  'arpu_3g_7',
#  'count_rech_3g_7',
#  'monthly_2g_7',
#  'loc_ic_mou_6',
#  'og_others_6',
#  'std_ic_t2f_mou_7',
#  'std_ic_t2m_mou_8',
#  'std_og_mou_8',
#  'onnet_mou_7',
#  'jul_vbc_3g',
#  'loc_ic_t2t_mou_8',
#  'ic_others_8',
#  'loc_og_t2t_mou_8',
#  'std_ic_t2t_mou_7',
#  'std_og_t2m_mou_7',
#  'spl_ic_mou_7',
#  'roam_ic_mou_6',
#  'total_ic_mou_8',
#  'spl_ic_mou_6',
#  'std_og_t2t_mou_8',
#  'loc_ic_t2m_mou_6',
#  'std_og_t2f_mou_6',
#  'max_rech_data_7',
#  'loc_ic_t2f_mou_7',
#  'max_rech_amt_6',
#  'sachet_3g_8',
#  'std_og_t2m_mou_8',
# ...

# %% [markdown]
# ## Univariate analysis

# %%
# Visualising Target variable
plt.figure(figsize=(10,10))
plt.pie(x=churn_data_eda['churn'].value_counts().values,labels=['non-churn','churn'],autopct = '%0.0f%%')
plt.show()

# %% [markdown]
# ---
# > Observation
#
# We can observe that there is an imbalance in the dataset. Around 91 % of the customers do not churn while only 9 % of them do churn.
#
# ---

# %%
# Visualising Target variable
c=1
plt.figure(figsize=(20,20))
for col in cat_cols:
    plt.subplot(6,3,c)
    plt.pie(x=churn_data_eda[col].value_counts().values,labels=['no','yes'],autopct = '%0.0f%%')
    plt.title('Distribution of {}'.format(col))
    c=c+1
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# > Observation
#
# We observe that a majority (~99%) of the users do not have a night pack. so these columns do not have any variance.
# Hence we drop the night pack users.
#
# However, there are significant fb_users, atleast close to 35 %.

# %%
def plot_numerical_monthly_plot(col_name):
  plt.figure(figsize=(15,20))
  plt.subplot(3,3,1)
  sns.boxplot(data=churn_data_eda, x='churn',y=col_name+'_6',showfliers=False)
  plt.xticks([0,1],labels=['non-churn','churn'])
  plt.title(' {} '.format(col_name+'_6'))
  plt.xlabel('')
  
  plt.subplot(3,3,2)
  sns.boxplot(data=churn_data_eda, x='churn',y=col_name+'_7',showfliers=False)
  plt.xticks([0,1],labels=['non-churn','churn'])
  plt.title(' {} '.format(col_name+'_7'))
  plt.xlabel('')
  
  plt.subplot(3,3,3)
  sns.boxplot(data=churn_data_eda, x='churn',y=col_name+'_8',showfliers=False)
  plt.xticks([0,1],labels=['non-churn','churn'])
  plt.title(' {} '.format(col_name+'_8'))
  plt.xlabel('')
  plt.tight_layout()
  plt.show()

# %%
plot_numerical_monthly_plot(col_name='arpu')

# %%
plot_numerical_monthly_plot(col_name='total_og_mou')
plot_numerical_monthly_plot(col_name='total_ic_mou')

# %%
plot_numerical_monthly_plot(col_name='total_rech_num')
plot_numerical_monthly_plot(col_name='total_rech_amt')
plot_numerical_monthly_plot(col_name='max_rech_amt')

# %%
plot_numerical_monthly_plot(col_name='total_rech_data')
plot_numerical_monthly_plot(col_name='max_rech_data')
plot_numerical_monthly_plot(col_name='av_rech_amt_data')

# %%
plot_numerical_monthly_plot(col_name='vol_2g_mb')
plot_numerical_monthly_plot(col_name='vol_3g_mb')

# %%
vol_3g_mb_6

# %%
churn_data_eda.columns
# Out:
# Index(['mobile_number', 'arpu_6', 'arpu_7', 'arpu_8', 'onnet_mou_6',
#        'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6', 'offnet_mou_7',
#        'offnet_mou_8', 'roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8',
#        'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8', 'loc_og_t2t_mou_6',
#        'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2m_mou_6',
#        'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_6',
#        'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_6',
#        'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_mou_6', 'loc_og_mou_7',
#        'loc_og_mou_8', 'std_og_t2t_mou_6', 'std_og_t2t_mou_7',
#        'std_og_t2t_mou_8', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7',
#        'std_og_t2m_mou_8', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7',
#        'std_og_t2f_mou_8', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8',
#        'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'spl_og_mou_6',
# ...

# %%
aaa

# %%
# Copied


##Continuous features
cont_cols_hv= [i for i in churn_data_eda.columns if i not in ['mobile_number', 'churn', 'tenure']]
cont_cols_hv

##Using numpy clip() to cap the values of outliers in between 1 and 99.9 percentiles
import numpy as np
for col in cont_cols_hv:
    percentiles = churn_data_eda[col].quantile([0.01,0.999]).values
    churn_data_eda[col] = np.clip(churn_data_eda[col], percentiles[0], percentiles[1])

# %%
churn_data_eda.isna().sum()
# Out:
# mobile_number            0
# arpu_6                   0
# arpu_7                   0
# arpu_8                   0
# onnet_mou_6              0
# onnet_mou_7              0
# onnet_mou_8              0
# offnet_mou_6             0
# offnet_mou_7             0
# offnet_mou_8             0
# roam_ic_mou_6            0
# roam_ic_mou_7            0
# roam_ic_mou_8            0
# roam_og_mou_6            0
# roam_og_mou_7            0
# roam_og_mou_8            0
# loc_og_t2t_mou_6         0
# loc_og_t2t_mou_7         0
# loc_og_t2t_mou_8         0
# loc_og_t2m_mou_6         0
# loc_og_t2m_mou_7         0
# loc_og_t2m_mou_8         0
# loc_og_t2f_mou_6         0
# loc_og_t2f_mou_7         0
# loc_og_t2f_mou_8         0
# loc_og_t2c_mou_6         0
# loc_og_t2c_mou_7         0
# loc_og_t2c_mou_8         0
# loc_og_mou_6             0
# loc_og_mou_7             0
# loc_og_mou_8             0
# std_og_t2t_mou_6         0
# std_og_t2t_mou_7         0
# std_og_t2t_mou_8         0
# ...

# %%
list(churn_data.columns[churn_data.columns.str.contains('data')])
# Out:
# ['total_rech_data_6',
#  'total_rech_data_7',
#  'total_rech_data_8',
#  'max_rech_data_6',
#  'max_rech_data_7',
#  'max_rech_data_8',
#  'av_rech_amt_data_6',
#  'av_rech_amt_data_7',
#  'av_rech_amt_data_8']
